# %%
import numpy as np
x = np.load("/mnt/lustre-grete/usr/u12008/neuron_representations/k_8_a_09_b1e7_poisson/k_8_a_09_xyz_nosubsel_1dLL_lrx04_meanbias_2dpe_bef_core_bs_16_frac0_05_s_1/queries/sel_frac_0.0/train/0.npy", mmap_mode="r").astype(np.float32)
thr = 60000.0
frac = (np.abs(x) > thr).mean()
print("fraction clipped:", frac)
# Out:
# Running cells with 'Python 3.11.13' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/bin/python3.11 -m pip install ipykernel -U --user --force-reinstall'
